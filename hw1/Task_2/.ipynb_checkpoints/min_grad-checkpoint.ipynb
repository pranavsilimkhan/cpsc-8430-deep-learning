# %%
import numpy as np

# %%
import torch
import matplotlib.pyplot as plt

# %%
import torch.nn as nn

# %%
#Define the input
ip = np.expand_dims(np.arange(-1.5, 1.5, 0.01),1)

#We'll be using sinc() function to generate output
op = np.sinc(5*ip)

# %%
# Shape of x and y
print(ip.shape)
print(op.shape)
# Out:
# (300, 1)
# (300, 1)

# %%
# Convert np arr to tensors
x = torch.tensor(ip, dtype=torch.float32)
y = torch.tensor(op, dtype=torch.float32)

# %%
# Graph for the function
plt.figure(figsize=(10,4))
plt.plot(x, y, color = "orange")
plt.title('sinc() plot')
plt.xlabel('Input')
plt.ylabel('Output')
plt.show()

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.linear_1 = nn.Linear(1, 4)
        self.linear_2 = nn.Linear(4, 9)
        self.linear_3 = nn.Linear(9, 12)
        self.linear_4 = nn.Linear(12, 10)
        self.linear_5 = nn.Linear(10, 10)
        self.linear_6 = nn.Linear(10, 10)
        self.linear_7 = nn.Linear(10, 4)
        self.predict = nn.Linear(4, 1)
    
    def forward(self,x):
        x = nn.functional.leaky_relu(self.linear_1(x))
        x = nn.functional.leaky_relu(self.linear_2(x))
        x = nn.functional.leaky_relu(self.linear_3(x))
        x = nn.functional.leaky_relu(self.linear_4(x))
        x = nn.functional.leaky_relu(self.linear_5(x))
        x = nn.functional.leaky_relu(self.linear_6(x))
        x = nn.functional.leaky_relu(self.linear_7(x))

        x = self.predict(x)
        return x

# %%
model = Model()
total_params = sum(p.numel() for p in model.parameters())
print('Total params - ', total_params)
# Out:
# Total params -  572

# %%
def train_model(model, x, y):
    epoch_size = 4000
    loss_arr = []
    epoch_arr = []
    grad_arr = []
    converged = False
    min_grad = 0
    loss_val=0
    print('Begining training')
    
    for epoch in range(epoch_size):
        if(converged):
            return epoch_arr, loss_arr, y_prediction, grad_arr

        y_prediction = model(x)
        lossm_val = 0.001
        loss = loss_func(y_prediction, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_arr.append(epoch)
        loss_arr.append(loss.detach().numpy())
        
        #Calculate the gradiet
        grad_all = 0.0
        for p in model.parameters():
            grad = 0.0
            if p.grad is not None:
                grad = (p.grad.cpu().data.numpy()**2).sum()
            grad_all += grad
        grad_norm = grad_all ** 0.5
        
        grad_arr.append(grad_norm)
        
        total_params=sum(p.numel() for p in model.parameters())
        if grad_norm < 0.001 or epoch == epoch_size:
            print('Gradient norm reached minimum value')
            predicted_y = model(x)
            lossm=loss_func(predicted_y,y)
            H = torch.zeros((total_params, total_params))

            Jacob = torch.autograd.grad(lossm, list(model.parameters()), create_graph=True)
            Jacob = torch.cat([e.flatten() for e in Jacob]) # flatten
            for i in range(total_params):
                result = torch.autograd.grad(Jacob[i], list(model.parameters()), retain_graph=True)
                H[i] = torch.cat([r.flatten() for r in result]) # flatten
            H_eig=torch.symeig(H).eigenvalues
            positive_count=0
            for i in H_eig.tolist():
                if(i>0):
                    positive_count+=1
            minimal_ratio = positive_count/H.shape[0]
            print('Minimal Ratio - ',minimal_ratio, ' , Loss - ', lossm.data.detach().numpy(), ' Erpoch - ', epoch)
            lossm_val=lossm.data.detach().numpy()
            break
            
                
    print('Training Completed')
    return lossm_val,minimal_ratio

# %%
loss_arr = []
min_ratio_arr = []
for index in range(100):
    print("Training model ", index)
    model = Model()
    loss_func = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3, weight_decay = 1e-5)

    loss_value, min_ratio = train_model(model, x, y)
    loss_arr.append(loss_value)
    min_ratio_arr.append(min_ratio)
# Out:
# Training model  0
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5192307692307693  , Loss -  0.0037210996  Erpoch -  714
# Training Completed
# Training model  1
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5332167832167832  , Loss -  0.0015926466  Erpoch -  2005
# Training Completed
# Training model  2
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5  , Loss -  0.06131342  Erpoch -  144
# Training Completed
# Training model  3
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5367132867132867  , Loss -  0.0011833668  Erpoch -  1407
# Training Completed
# Training model  4
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.506993006993007  , Loss -  0.06124682  Erpoch -  167
# Training Completed
# Training model  5
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.534965034965035  , Loss -  0.001407654  Erpoch -  1314
# Training Completed
# Training model  6
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5332167832167832  , Loss -  0.0011788533  Erpoch -  1018
# Training Completed
# Training model  7
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5227272727272727  , Loss -  0.005386352  Erpoch -  495
# Training Completed
# Training model  8
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5314685314685315  , Loss -  0.0022779459  Erpoch -  471
# Training Completed
# Training model  9
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.541958041958042  , Loss -  0.0020491502  Erpoch -  1029
# Training Completed
# Training model  10
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5437062937062938  , Loss -  0.0010673382  Erpoch -  1496
# Training Completed
# Training model  11
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5  , Loss -  0.06130224  Erpoch -  76
# Training Completed
# Training model  12
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.527972027972028  , Loss -  0.0014050273  Erpoch -  898
# Training Completed
# Training model  13
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5332167832167832  , Loss -  0.0020413743  Erpoch -  712
# Training Completed
# Training model  14
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5384615384615384  , Loss -  0.0016935021  Erpoch -  833
# Training Completed
# Training model  15
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5367132867132867  , Loss -  0.0020432577  Erpoch -  1564
# Training Completed
# Training model  16
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5  , Loss -  0.06130104  Erpoch -  40
# Training Completed
# Training model  17
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.527972027972028  , Loss -  0.0049842345  Erpoch -  486
# Training Completed
# Training model  18
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5034965034965035  , Loss -  0.06121497  Erpoch -  163
# Training Completed
# Training model  19
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5384615384615384  , Loss -  0.0022344075  Erpoch -  1251
# Training Completed
# Training model  20
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5402097902097902  , Loss -  0.0012241596  Erpoch -  763
# Training Completed
# Training model  21
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5367132867132867  , Loss -  0.0020321296  Erpoch -  940
# Training Completed
# Training model  22
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5157342657342657  , Loss -  0.0047425865  Erpoch -  684
# Training Completed
# Training model  23
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5332167832167832  , Loss -  0.00220129  Erpoch -  517
# Training Completed
# Training model  24
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5402097902097902  , Loss -  0.0022351653  Erpoch -  1784
# Training Completed
# Training model  25
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5454545454545454  , Loss -  0.0020589894  Erpoch -  1235
# Training Completed
# Training model  26
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5  , Loss -  0.061221175  Erpoch -  46
# Training Completed
# Training model  27
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5367132867132867  , Loss -  0.0014597953  Erpoch -  1235
# Training Completed
# Training model  28
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5367132867132867  , Loss -  0.0019032654  Erpoch -  920
# Training Completed
# Training model  29
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.4982517482517482  , Loss -  0.06131029  Erpoch -  13
# Training Completed
# Training model  30
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5  , Loss -  0.061272964  Erpoch -  64
# Training Completed
# Training model  31
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5034965034965035  , Loss -  0.06129439  Erpoch -  126
# Training Completed
# Training model  32
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.506993006993007  , Loss -  0.06126934  Erpoch -  91
# Training Completed
# Training model  33
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5332167832167832  , Loss -  0.0021524592  Erpoch -  645
# Training Completed
# Training model  34
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5192307692307693  , Loss -  0.00505205  Erpoch -  1007
# Training Completed
# Training model  35
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5052447552447552  , Loss -  0.061291706  Erpoch -  87
# Training Completed
# Training model  36
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5297202797202797  , Loss -  0.00290441  Erpoch -  1264
# Training Completed
# Training model  37
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5017482517482518  , Loss -  0.061311893  Erpoch -  27
# Training Completed
# Training model  38
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5017482517482518  , Loss -  0.061306592  Erpoch -  29
# Training Completed
# Training model  39
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5174825174825175  , Loss -  0.005592398  Erpoch -  555
# Training Completed
# Training model  40
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.513986013986014  , Loss -  0.0055511915  Erpoch -  452
# Training Completed
# Training model  41
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5541958041958042  , Loss -  0.00067787885  Erpoch -  1770
# Training Completed
# Training model  42
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5244755244755245  , Loss -  0.0022693374  Erpoch -  587
# Training Completed
# Training model  43
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5017482517482518  , Loss -  0.061248995  Erpoch -  191
# Training Completed
# Training model  44
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5244755244755245  , Loss -  0.0023210056  Erpoch -  1016
# Training Completed
# Training model  45
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5052447552447552  , Loss -  0.06130421  Erpoch -  38
# Training Completed
# Training model  46
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5034965034965035  , Loss -  0.061302453  Erpoch -  91
# Training Completed
# Training model  47
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5559440559440559  , Loss -  8.215279e-05  Erpoch -  2189
# Training Completed
# Training model  48
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5052447552447552  , Loss -  0.06125909  Erpoch -  56
# Training Completed
# Training model  49
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5017482517482518  , Loss -  0.06130995  Erpoch -  109
# Training Completed
# Training model  50
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5157342657342657  , Loss -  0.0054587033  Erpoch -  528
# Training Completed
# Training model  51
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5314685314685315  , Loss -  0.0022759477  Erpoch -  614
# Training Completed
# Training model  52
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.548951048951049  , Loss -  0.0012043972  Erpoch -  1209
# Training Completed
# Training model  53
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5506993006993007  , Loss -  0.0012145307  Erpoch -  1265
# Training Completed
# Training model  54
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5384615384615384  , Loss -  0.002538836  Erpoch -  3316
# Training Completed
# Training model  55
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5472027972027972  , Loss -  0.0010490449  Erpoch -  690
# Training Completed
# Training model  56
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5506993006993007  , Loss -  0.00053704093  Erpoch -  1770
# Training Completed
# Training model  57
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5227272727272727  , Loss -  0.0054654004  Erpoch -  649
# Training Completed
# Training model  58
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5262237762237763  , Loss -  0.003943925  Erpoch -  549
# Training Completed
# Training model  59
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5034965034965035  , Loss -  0.06131308  Erpoch -  34
# Training Completed
# Training model  60
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5332167832167832  , Loss -  0.002234484  Erpoch -  653
# Training Completed
# Training model  61
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5559440559440559  , Loss -  0.00053856295  Erpoch -  3093
# Training Completed
# Training model  62
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5  , Loss -  0.061304275  Erpoch -  20
# Training Completed
# Training model  63
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5227272727272727  , Loss -  0.002208782  Erpoch -  961
# Training Completed
# Training model  64
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5122377622377622  , Loss -  0.0053394265  Erpoch -  698
# Training Completed
# Training model  65
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.534965034965035  , Loss -  0.0018764309  Erpoch -  1845
# Training Completed
# Training model  66
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5227272727272727  , Loss -  0.0022426967  Erpoch -  983
# Training Completed
# Training model  67
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5332167832167832  , Loss -  0.0022547634  Erpoch -  1174
# Training Completed
# Training model  68
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.527972027972028  , Loss -  0.0022435132  Erpoch -  564
# Training Completed
# Training model  69
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5384615384615384  , Loss -  0.0007075641  Erpoch -  825
# Training Completed
# Training model  70
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5  , Loss -  0.06131021  Erpoch -  185
# Training Completed
# Training model  71
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5  , Loss -  0.06130937  Erpoch -  49
# Training Completed
# Training model  72
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5402097902097902  , Loss -  0.0015824006  Erpoch -  554
# Training Completed
# Training model  73
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.534965034965035  , Loss -  0.002261018  Erpoch -  584
# Training Completed
# Training model  74
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5402097902097902  , Loss -  0.00085035386  Erpoch -  1552
# Training Completed
# Training model  75
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.548951048951049  , Loss -  0.0012515935  Erpoch -  1467
# Training Completed
# Training model  76
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.4982517482517482  , Loss -  0.061322976  Erpoch -  3
# Training Completed
# Training model  77
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5209790209790209  , Loss -  0.0022382657  Erpoch -  753
# Training Completed
# Training model  78
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5244755244755245  , Loss -  0.0023664928  Erpoch -  927
# Training Completed
# Training model  79
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5402097902097902  , Loss -  0.0011743385  Erpoch -  856
# Training Completed
# Training model  80
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5192307692307693  , Loss -  0.00520269  Erpoch -  629
# Training Completed
# Training model  81
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5017482517482518  , Loss -  0.061321285  Erpoch -  50
# Training Completed
# Training model  82
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5157342657342657  , Loss -  0.005670515  Erpoch -  298
# Training Completed
# Training model  83
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5052447552447552  , Loss -  0.061266497  Erpoch -  40
# Training Completed
# Training model  84
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5367132867132867  , Loss -  0.002311448  Erpoch -  536
# Training Completed
# Training model  85
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5402097902097902  , Loss -  0.0011629029  Erpoch -  1388
# Training Completed
# Training model  86
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.506993006993007  , Loss -  0.061258867  Erpoch -  81
# Training Completed
# Training model  87
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5541958041958042  , Loss -  0.0025250316  Erpoch -  1743
# Training Completed
# Training model  88
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.534965034965035  , Loss -  0.0035275014  Erpoch -  1461
# Training Completed
# Training model  89
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.527972027972028  , Loss -  0.0021266574  Erpoch -  1201
# Training Completed
# Training model  90
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5367132867132867  , Loss -  0.0016171866  Erpoch -  1431
# Training Completed
# Training model  91
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5367132867132867  , Loss -  0.0014021427  Erpoch -  1546
# Training Completed
# Training model  92
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5034965034965035  , Loss -  0.061311956  Erpoch -  53
# Training Completed
# Training model  93
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5052447552447552  , Loss -  0.061089795  Erpoch -  567
# Training Completed
# Training model  94
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5262237762237763  , Loss -  0.0019356946  Erpoch -  744
# Training Completed
# Training model  95
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.527972027972028  , Loss -  0.0023915549  Erpoch -  661
# Training Completed
# Training model  96
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5017482517482518  , Loss -  0.061285444  Erpoch -  147
# Training Completed
# Training model  97
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5  , Loss -  0.061309304  Erpoch -  89
# Training Completed
# Training model  98
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5244755244755245  , Loss -  0.0021937273  Erpoch -  752
# Training Completed
# Training model  99
# Begining training
# Gradient norm reached minimum value
# Minimal Ratio -  0.5  , Loss -  0.061310064  Erpoch -  3
# Training Completed

# %%
plt.scatter(min_ratio_arr,loss_arr, color = "orange")
plt.xlabel("Minimal Ratio")
plt.ylabel("Loss")
plt.show()
